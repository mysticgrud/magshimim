# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticgrud/magshimim/blob/class-3/%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_Copy_of_%D7%AA%D7%A8%D7%92%D7%95%D7%9C_%D7%94%D7%99%D7%9B%D7%A8%D7%95%D7%AA_%D7%A2%D7%9D_%D7%A4%D7%99%D7%99%D7%AA%D7%95%D7%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![up.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
# שיעור 2</font></b>
# <H1>
# <font color='#141C3A'>
# <b></b>
# </font>
# </H1>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="8">
# <b>
# תרגיל כיתה - היכרות עם פייתון
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# כיצד ניתן לעבוד על מחברת הקולאב?
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# זוכרים את דף התשובות ממטלת הבית האחרונה?
# <br>
# לא היינו יכולים לערוך אותו ולכן היינו צריכים ליצור עותק משל עצמנו ולעבוד על העותק
# <br></br>
# גם במחברות הקולאב זהו המקרה. על מנת ליצור עותק למחברת הזו עליכם ללחוץ על הכפתור:
# <b>Copy to Drive ♻</b>
# <br>
# תוכלו למצוא את הכפתור בתפריט העליון ליד הכפתורים:
# <b>Code + Text +</b>
#
# </font>
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תזכורת - הפקודה print
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>תזכורת:</b>
# פקודת ההדפסה בפייתון נקראת print. להלן דוגמה למספר הדפסות והפלט שלהן:
# </div>
#
#
# ```
# print("This is the second lesson of Magshimim AI")
#
# Output: This is the second lesson of Magshimim AI
# ```
# ```
# print("3 + 6")
#
# Output: 3 + 6
# ```
# ```
# print(3 + 6)
#
# Output: 9
# ```

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 1 - התכנית הראשונה שלי
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# המנהג בעולם התכנות הוא ששורת הקוד הראשונה שמתכנת מתחיל יכתוב תהיה הדפסה של המילים Hello World
# <br></br>
# כמובן שאנחנו לא נשבור את המנהג..
# <br>
# <b>כתבו בתא הקוד מלמטה פקודת הדפסה כך שבזמן ההרצה, הפלט מהמחשב יהיה Hello World!</b>
# </font>
# </div>

# %%
# כתבו את הקוד כאן
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <br>
# <b>תזכורת:</b>
# במידה ונרצה להריץ את הקוד ולקבל פלט מהמחשב נלחץ על הכפתור ▶ משמאל לתא הקוד
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 2 - התנסות עם פקודות בסיסיות
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# כעת נכתוב קוד שיש בו מספר הדפסות
# <br></br>
# כתבו באותה המשבצת קוד את ההדפסות הבאות:
# <br>
# <ul>
#     <li>הדפיסו את השם שלכם באנגלית</li>
#     <li>הדפיסו את העיר בה אתם גרים באנגלית</li>
#     <li>הדפיסו את הצורה הבאה:</li>
# </ul>
# </font>
# </div>
#
#
# ```
#   *
#  ***
# *****
# ```

# %%
#כתבו את הקוד כאן
print("  *")
print(" ***")
print('*****')
# Out:
#   *
#  ***
# *****

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# הריצו את קטע הקוד הבא:
# <br>
# </font>
# </div>

# %% [markdown]
# מה שקרה זה שלא סגרו את הסוגריים

# %%
print("Hello World!"

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b> מה לדעתכם קרה? </b>
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
#
# ![image.png](data:image/png;base64,...)
# <br><br>
#
# <font color="red" size="8"><b>
# עצרו כאן! חכו להוראות המדריך ולהמשך המצגת
# </b></font><br><br><br>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 3 - תוכן משתנה
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# השלימו את הקוד על פי ההוראות:
# <br>
# </font>
# </div>

# %%
height = 1.7
age = 16
how_i_call_it = 'Kartiv'
name = "Dana"
print("Dana")  # השלימו כך שהדפסה זו תציג את השם
print("16")  # השלימו כך שהדפסה זו תציג את הגיל
print("1.7")  # השלימו כך שהדפסה זו תציג את הגובה
print('Kartiv')  # השלימו כך שהדפסה זו תציג את המשתנה איך אני קורא לזה

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 4 - שילוב משתנים ומחרוזות בפקודות הדפסה
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>תזכורת:</b>
# אנחנו יכולים להשתמש בסימן "פסיק" בתוך פקודת ה-print, ככה נוכל להפריד בין הטקסט שנרצה לכתוב לבין המשתנה שלנו:
# <br>
# </font>
# </div>
#
#
#
# ```
# my_name = "LeBron"
# my_proffesion = "basketball"
#
# print("Hello Magshimim AI, My name is:", my_name)
# print("Hello Magshimim AI, My name is:", my_name, "And I am a", my_proffesion, "Player")
# ```

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>השתמשו במשתנים שנתונים בתא הקוד על מנת לבצע את ההדפסות הבאות:</b>
# <br>
# </font>
# </div>
#
# `My name is Dana`
# <br>
# `I am 16 years old `
# <br>
# `My favorite Ice Cream is Kartiv, a box of it costs only 19 shekels!`

# %%
box_price = 19
age = 16
favorite_ice_cream = 'Kartiv'
name = "Dana"
# השלימו את ההדפסות כאן
print("My name is Dana")
print("I am 16 years old")
print("My favorite Ice Cream is Kartiv, a box of it costs only 19 shekels!")
# Out:
# My name is Dana
# I am 16 years old
# My favorite Ice Cream is Kartiv, a box of it costs only 19 shekels!

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 5 - קונבנציות כתיבת קוד
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>תזכורת:</b>
# כאשר נכתוב קוד עלינו לוודא כי ניתן להבין את הפלט של הרצת הקוד שלנו מבלי לקרוא את הקוד עצמו
# <br><br>
# אליס ובוב מעוניינים לטוס לחו"ל, הם מעוניינים לדעת מה היעד הבא המתאים עבורם וכמה כסף יש להם בבנק
# <br>
# <b>עקבו אחר ההוראות הבאות:</b>
# <br>
# <ul>
#     <li>
#     צרו 2 משתנים אשר מכילים את סכום הכסף שנותר בבנק לאליס ולבוב(משתנה לכל אחד בנפרד) - וודאו כי למשתנים יש שמות משמעותיים לפי הקונבנציות שראינו בשיעור
#     </li>
#     <br>
#     <li>
#      צרו 2 משתנים אשר מכילים את היעד הבא של אליס ושל בוב(משתנה לכל אחד בנפרד) - וודאו כי למשתנים יש שמות משמעותיים לפי הקונבנציות שראינו בשיעור
#     </li>
#     <br>
#     <li>
#     הדפיסו 2 הודעות מפורטות על המסך - אחת לאליס ואחת לבוב, אשר כוללות את כל המידע שאליס ובוב צריכים לדעת(כמה כסף יש להם בבנק ומה היעד הבא שלהם)
#     </li>
# </ul>
# </font>
# </div>

# %%
# כתבו את הקוד כאן
bob_money = "100"
alice_money = "150"
destination= "france"
destination2 = "germany"
print("alice has ", alice_money, " shekles in her account and her next destination is ", destination)
print("bob has ", bob_money, " shekles in his account and his next destination is ", destination2)
# Out:
# alice has  150  shekles in her account and her next destination is  france
# bob has  100  shekles in his account and his next destination is  germany

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>לנוחיותכם:</b>
# צירפנו את טבלת הקונבנציות מהמצגת
# </font>
# </div>

# %% [markdown]
# ![DoDontDo1.png](data:image/png;base64,...)
#
# ![DoDontDo2.png](data:image/png;base64,...)

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="6">
# <b>
# מה שלא סיימתם בכיתה עובר לבית
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
#
# ![image.png](data:image/png;base64,...)
# <br><br>
#
# <font color="red" size="8"><b>
# עצרו כאן! המשיכו למטלת הבית רק אם נותר לכם זמן בתרגיל הכיתה
# </b></font><br>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="8">
# <b>
# מטלת בית - היכרות עם פייתון
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# במהלך תרגילי הקולאב יהיה עליכם לפעמים לענות תשובות מילוליות על שאלות שנשאל אותכם, אתם תדעו שעליכם לעשות זאת כאשר תראו את תא הטקסט עם הכיתוב הכחול.
# <br></br>
# על מנת לענות, עליכם להקליק על התא פעמיים, ולאחר מכן להחליף את המילים "ענו כאן" בתשובה שלכם.
# <br>
# <b>נסו זאת כעת:</b>
# החליפו את המילים "ענו כאן" בשם שלכם.
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 1 - אופרטורים מתמטיים
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# סעיף א'
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b> תזכורת:</b>
# בשיעור האחרון ראינו 3 סוגי משתנים:
# <b>מספרים שלמים, מספרים עשרוניים, מחרוזות</b>.
# <br>
# רוב ההדפסות שביצענו בשיעור ובתרגול הכיתה היו של מחרוזות, אך מסתבר שפייתון יודע לבצע חישובים מתמטיים עם מספרים.
# <br>
# <b>אופרטור:</b>
# תו המייצג פעולה כלשהי
# <br>
# <b>התווים + - * /</b>
# הם אופרטורים מתמטיים מכיוון שהם תווים שמבצעים פעולה מתמטית
# <br></br>
# פתרו את התרגילים המתמטיים הבאים באמצעות הדפסות של פייתון.
# <br>
# <b>הערה:</b>
# בתרגיל זה אין צורך לדאוג להדפסות ברורות ומפורטות.
# </font>
# </div>
#
# ```
# 2+9
# 5/2
# 2+3*9
# (2+3)*9
# 2-3
# -1*(2-3)
# (2-3)*-1
# (2-3)*(-1-5)
# ((1+2)*3)-4.5
# ```

# %%
#כתבו את ההדפסות כאן
print(2+9)
print(5/2)
print(2+3*9)
print((2+3)*9)
print(2-3)
print(-1*(2-3))
print((2-3)*-1)
print((2-3)*(-1*-5))
print(((1+2)*3)-4.5)
# Out:
# 11
# 2.5
# 29
# 45
# -1
# 1
# 1
# -5
# 4.5

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הריצו את קטע הקוד הבא:</b>

# %%
#הריצו את קטע הקוד
print(2**4)
# Out:
# 16

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# מה האופרטור ** מבצע? אתם מוזמנים לשחק עם המספרים כדי לראות עוד דוגמאות
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# האופרטור ** מבצע חזקה

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# סעיף ב'
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b> הידעתם:</b>
# עד כה ביצענו אופרטורים מתמטיים אך ורק בין מספרים
# <br>
# מה יקרה אם נשתמש במשתנים מוגדרים מראש ועליהם נבצע אופרטורים מתמטיים?
# <br></br>
# <b>הריצו את קטע הקוד הבא:</b>

# %%
#הריצו
my_money = 1000
friend_money = 2000

print(my_money + friend_money)
# Out:
# 3000

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# במידה ואנו מבצעים אופרטור מתמטי(כלומר פעולה מתמטית) בין משתנים, מומלץ ליצור משתנה חדש לכך מכיוון שהקוד יראה הרבה יותר "נקי" ומובן:

# %%
#הריצו
my_money = 1000
friend_money = 2000
total_money = my_money + friend_money

print(total_money)
# Out:
# 3000

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# כמובן שהקוד שלנו צריך לעמוד בקונבנציות ההדפסה, כלומר שההדפסה תהיה מפורטת ולא יהיה צורך להסתכל בקוד על מנת להבין מה מודפס
# <br></br>
# <b>ערכו את הקוד כך שההדפסה תהיה מפורטת ואחרים לא יצטרכו להסתכל בקוד על מנת להבין אותה:</b>
# <b></b>

# %%
#שנו את ההדפסה
my_money = 1000
friend_money = 2000
total_money = my_money + friend_money

print("the total amount of money between my friend and i is: ", total_money)
# Out:
# the total amount of money between my friend and i is:  3000

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>שימו לב:</b>
# ההדפסה הבאה לא תהיה טובה:
# <br>
# </font>
# </div>
#
#
# ```
# print("The value of total_money is:", total_money)
# ```
# <div dir="rtl" align="right">
# <font  size="4">
# <b>נסו לחשוב מדוע וענו:</b>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ההדפסה לא תיהיה טובה בגלל שמשתמשים בשם משתמש עצמו, שזה ניראה מוזר ואי אפשר להבין מההדפסה מה זה אמור להיות

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# סעיף ב'
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# אתם מארחים חברים אצלכם בבית ורוצים להזמין פיצות:
# <br>
# <ul>
#     <li>הגדירו משתנה אשר יכיל את מספר החברים שמגיעים - וודאו כי שם המשתנה עומד בקונבנציות </li>
#     <li>הגדירו משתנה אשר יכיל את מספר משולשי הפיצה שכל חבר יאכל(ניתן להניח שכולם אוכלים את אותה הכמות) - גם כאן וודאו כי שם המשתנה עומד בקונבנציות</li>
#     <li>הדפיסו הודעה מפורטת אשר תכלול את מספר משולשי הפיצה עליכם להזמין בסך הכל
#     </li>
# </ul>
# </font>
# </div>

# %%
#כתבו את הקוד כאן
friends_num = 9
pizzaslices_perfriend = 3
print("the amount of pizza slices you must order is: ", friends_num * pizzaslices_perfriend)
# Out:
# the amount of pizza slices you must order is:  27

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>תזכורת:</b>
# במידה ואנו מבצעים אופרטור מתמטי(כלומר פעולה מתמטית) בין משתנים, מומלץ ליצור משתנה חדש לכך מכיוון שהקוד יראה הרבה יותר נקי
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# סעיף ג'
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# אתם אושיות אינסטגרם ואתם רוצים לבדוק את ממוצע העוקבים שעלו לכם בכל יום
# <br>
# <ul>
#     <li>הגדירו משתנה שמייצג את כמות העוקבים שהתחלתן איתה </li>
#     <li>הגדירו משתנה שמייצג את כמות העוקבים שיש לכם היום</li>
#     <li>הגדירו משתנה שמייצג את מספר הימים שעברו מהיום שהתחלתם לבדוק את העוקבים</li>
#     <li>הדפיסו את מספר העוקבים אשר עלה לכם בממוצע כל יום</li>
# </ul>
# </font>
# </div>

# %%
#כתבו את הקוד כאן
start_followers = 0
current_followers = 200
days_since_start= 10
print("average amount of followers per day: ", (current_followers-start_followers)/days_since_start)
# Out:
# average amount of followers per day:  20.0

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# סעיף ד' - אתגר
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# בתרגיל זה עליכם יהיה לחשב את אורך היתר במשולש ישר זווית.
# <br>
# <ul>
#     <li>הגדירו שני משתנים אשר מייצגים את 2 הצלעות היוצרות 90 מעלות במשולש </li>
#     <li>הדפיסו הודעה מפורטת אשר מחשבת את אורך הצלע השלישית לפי משפט פיתגורס</li>
#     <li>שחקו עם הערכים של המשתנים והריצו מספר פעמים את הקוד על מנת לוודא שהחישוב שלכם תקין</li>
# </ul>
# </font>
# </div>

# %%
#כתבו את הקוד כאן
side = 3
side2 = 4
pythagoras = ((side**2) + (side2**2))**0.5
print("hypotenuse =", pythagoras)
# Out:
# hypotenuse = 5.0

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>טיפ:</b>
# לבצע פעולת שורש על מספר זה כמו להעלות אותו בחזקת 0.5
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 2 - שמות משתנים אסורים
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b> תזכורת:</b>
# בשיעור האחרון ראינו כי אסור לתת למשתנים שמות של פקודות קיימות בפייתון,
# <b>לדוגמה: print</b>.
# <br>
# אך לא הסברנו מדוע אסור לעשות זאת, אנחנו מאמינים כי במקום להסביר עדיף פשוט להראות לכם.
# <br></br>
#
# הריצו את קטע הקוד הבא בו יצרנו משתנה בשם `print` והגדרנו אותו להכיל את הערך 5:
# </font>
# </div>

# %%
# הריצו את הקוד
#print = 5

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# נראה שהכל עובד כרגיל נכון?
# <br>
# הריצו את קטע הקוד הבא:
# </font>
# </div>

# %%
print("Hello MagshimimAI!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-1030526735b7> in <cell line: 1>()
# ----> 1 print("Hello MagshimimAI!")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הפקודה print לא עובדת יותר!</b>
# <br>
# כאשר הגדרנו משתנה שקוראים לו print, דרסנו את הפקודה וכעת אנחנו לא יכולים להשתמש בה.
# <br></br>
# הדרך היחידה להחזיר את print לעבוד ולבצע הדפסות היא לאפס את המחברת, נוכל לעשות זאת בצורה הבאה:
# <br>
# <ul>
#     <li>נלחץ על הכפתור Runtime בתפריט העליון</li>
#     <li> לאחר מכן נלחץ על Restart Runtime</li>
#     <li>נוכל גם ללחוץ על <b>Ctrl + M</b></li>
# </ul>
# <br></br>
# מעצבן נכון? יותר מכך, זה
# <b>מסוכן,</b>
# דריסה של פקודות קיימות בפייתון יכולה לגרום לבאגים מאוד גדולים בקוד שניצור, לכן
# <b>אסור</b>
# לתת למשתנים שמות של פקודות קיימות.
#
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 3 - קריאת שגיאות
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# `int object is not callable`
# <br>
# <font  size="4">
# <b>בתרגיל הקודם קיבלנו באג בקוד וביחד איתו קיבלנו הודעה שגיאה בואו ננסה להבין אותה:</b>
# <br>
# <ul>
#     <li> המשמעות של המילה int היא מספר שלם</li>
#     <li>המשמעות של המילה callable היא - "ניתנת לקריאה"</li>
# </ul>
# <br>
# קריאה בפייתון מתבצעת כאשר אנחנו משתמשים בסוגריים עגולות ( ), כאשר אנחנו משתמשים בפקודה print, אנחנו מבצעים קריאה לפקודה והקריאה לפקודה היא זו שגורמת להדפסה, נלמד על כך לעומק בהמשך.
# <br></br>
# כעת נוכל לתרגם את השגיאה שקיבלנו מאנגלית לעברית:
# <br>
# <b>אובייקט מסוג מספר שלם לא ניתן לקריאה</b>
# <br><br>
# <b>מה זה אומר:</b>
# הפקודה print
# <b>נדרסה</b>
# כאשר הרצנו את שורת הקוד הבאה:
# </font>
# </div>
#
# ```
# print = 5
# ```
#
# <div dir="rtl" align="right">
# <font  size="4">
# זה אומר שאנחנו לא יכולים  יותר להשתמש בה ולקרוא לה כמו שהיינו עד עכשיו, כי דרסנו את הפקודה להיות מספר שלם (5) ולכן אנחנו מקבלים שגיאה שלא ניתן לבצע קריאה למספר שלם
# <br>
#
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# לא ניתן לבצע קריאה למספרים בפייתון, הריצו את קטע הקוד הבא:
# </b>
# <br>
# </font>
# </div>

# %%
# הריצו את קטע הקוד הבא
number = 5
number()

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# קיבלנו בדיוק את אותה השגיאה שהייתה לנו למעלה
# <br>
# <b>
# גם מחרוזות לא ניתנות לקריאה, הריצו את קטע הקוד הבא:
# </b>
# <br>
# </font>
# </div>

# %%
hello_message = "Hello World"
hello_message()

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# כעת תורכם לנסות להבין שגיאה של פייתון.
# <br></br>
# הריצו את קטע הקוד הבא, תרגמו את השגיאה שמתקבלת והסבירו אותה בכמה שיותר פירוט:
# </font>
# </div>

# %%
#הריצו את קטע הקוד הבא
calculation = 5 / 0

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>תזכורת:</b>
# על מנת לענות על השאלה, הקליקו פעמיים על תא הטקסט בו כתוב "ענו כאן" והחליפו את הכיתוב לתשובה שלכם
# <br>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# השגיאה היא שניסו לחלק ב0 ולא ניתן לעשות זאת מבחינה מטמתית

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# לסוג הזה של שגיאות קוראים שגיאה ביצועית, כעת אנחנו מכירים 2 סוגי שגיאות:
# <br>
# <ul>
#     <li>שגיאה תחבירית(Syntax), למשל: print("hello</li>
#     <li>שגיאה ביצועית, למשל: 7/0 או למשל: ()5</li>
# </ul>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 4 - שרשור מחרוזות
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# עד כה ראינו שניתן להשתמש באופרטורים מתמטיים על מספרים, ידעתם שאפשר להשתמש באופרטור + על מחרוזות?
# <br>
# <b>הריצו את קטע הקוד הבא:</b>
# </font>
# </div>

# %%
# הריצו את קטע הקוד הבא
print("hello" + "world")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-91a00be4e6c8> in <cell line: 2>()
#       1 # הריצו את קטע הקוד הבא
# ----> 2 print("hello" + "world")
#
# TypeError: 'int' object is not callable

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# כמובן שניתן גם להשתמש בשרשור משתנים, אם שני המשתנים שלנו הם מסוג מחרוזת:
#
# </font>
# </div>

# %%
# הריצו את קטע הקוד הבא
first_word = "hello"
second_word = "world"
print(first_word + second_word)
# Out:
# helloworld

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# הפעולה הזו נקראת
# <b>שרשור מחרוזות,</b>
# ובשיעור הבא נרחיב עליה, ובאופן כללי על מחרוזות. אבל לפני שנגיע לשיעור הבא, נסו לבדוק:
# <br>
# <ul>
#     <li>א. האם ניתן להשתמש באופרטור + בין מחרוזת למספר שלם?</li>
#     <li>ב. האם ניתן להשתמש באופרטור - בין שני מחרוזות?</li>
#     <li>ג.האם ניתן להשתמש באופרטור * בין מחרוזת למספר שלם?</li>
#     <li>ד.האם ניתן להשתמש באופרטור * בין מחרוזת למספר עשרוני?</li>
# </ul>
# <br>
# </font>
# </div>

# %%
# בדקו כאן וענו על 4 הסעיפים
#print("hi" + 9)
#print("hi" - "h")
print("you" * 2)
#print("word" * 0.5)
# Out:
# youyou

# %% [markdown]
# לא
# לא
# כן
# לא

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# א.
# <br>
# ב.
# <br>
# ג.
# <br>
# ד.
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# שמירת המחברת
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# לאחר שסיימתם לענות על כל השאלות במחברת תוכלו להגיש אותה בדף התשובות.
# <br>
# הסבר מפורט להגשת מחברת ה-Colab נמצא בדף התשובות (תוכלו לנחש כבר כיצד עושים זאת)
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="6">
# <b>
# כל הכבוד! סיימתם את מטלת הבית התכנותית של השיעור השני!
# </b>
# </font>
# </div>

# %% [markdown]
# <H5 dir=rtl align=center>
#
# ![end2.png](data:image/png;base64,...)
#
# </H5>
