# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticgrud/magshimim/blob/class-16/%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_%D7%9E%D7%97%D7%91%D7%A8%D7%AA_%D7%97%D7%A0%D7%99%D7%9A_%D7%9E%D7%97%D7%A7%D7%A8_%D7%A1%D7%9B%D7%A8%D7%AA_%D7%94%D7%A8%D7%99%D7%95%D7%A0%D7%95%D7%AA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![up.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
# שיעור 16</font></b>
# <H1>
# <font color='#141C3A'>
# <b></b>
# </font>
# </H1>
# </div>

# %% [markdown]
# <div dir="rtl">
# <font color="Grey">
# זכרו ליצור עותק של מחברת זו, לשנות את שמו ולעבוד על העותק האישי שלכם.
# <br>
# בהצלחה!
# </font>
# </div>

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
#  טעינת הספריות
# </b></font>
#
# # היום נעסוק בנושא מרתק ונעבוד עם נתונים מהעולם האמיתי. לפני שנתחיל עלינו להבין מה מכילים הנתונים. תחילה נחקור את הנתונים/המדדים רפואיים של נשים בריאות ושל חולי סכרת שמופעים בטבלה.
#
#
#
# <h3 dir="rtl">
#
# **בשלב ראשון** אנא העלו את הקובץ מהדרייב לתוך טבלה של פנדס על מנת לחקור אותו</h3>
# הלינק לקובץ:
# https://drive.google.com/file/d/1mTrGReXJH6Jtj7ueFpWruOBezg8Jq0S7/view?usp=sharing
#
# </div>

# %%
# @title נטען אתה ספריות הרלוונטיות
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#נוסיף את קובץ הנתונים
import pandas as pd
import seaborn as sns

df = pd.read_csv('/content/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# <div dir="rtl">
#
# <font color="#6400E4" size="5"><b>
# חלק א- מחקר ראשוני
#
# </b></font>

# %% [markdown]
# <div dir="rtl">
#
# #איזה סוגי נתונים יש בטבלה? מה האופי שלהם?
# #איזה נתונים חסרים בטבלה ושווה שהטבלה תכיל?    (לפי הסרטון)

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# אכותיים בדידים ורציפים
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# #השתמשו במדתודה describe  וגלו פרטים נוספים, העזרו בריבעונים ונסו לגלות מידע אודות חלקים מסויימים של הנתונים ברבעון:

# %%
#השלימו קטע קוד
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# <div dir="rtl">
#
# # מה אנחנו מבינים עוד אודות הנתונים שלנו לאחר הפעלת המתודה? מה אפשר ללמוד מהמשתנה-Age?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# את גילי האימאות שבהריון
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
#
# #הידעתם שניתן להפעיל את describe  על עמודה אחת בלבד? איך עושים זאת לדעתכם? כתבו קטע קוד המתאים לעמודה BloodPressuer .

# %%
#השלימו קטע קוד
df["BloodPressure"].describe()
# Out:
# count    768.000000
# mean      69.105469
# std       19.355807
# min        0.000000
# 25%       62.000000
# 50%       72.000000
# 75%       80.000000
# max      122.000000
# Name: BloodPressure, dtype: float64

# %% [markdown]
# <div dir="rtl">
#
# #מה אפשר ללמוד  ממשתנה    BloodPressure (לחץ דם)?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# שלחץ הדם יכול להיות 0
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# #באמצעות איזה גרפים כדאי להציג משתנים אלה?
# # באמצעות ספריית סיברון הציגו גרף מתאים למשתנה גיל ולחץ דם, כתבו מסקנות חדשות שהסקתם מהייצוג הגרפי

# %%
#כתבו קטע קטע קוד כאן עבור משתנה גיל
sns.histplot(data=df, x="Age",color='pink')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#כתבו קטע קטע קוד כאן עבור משתנה לחץ דם
sns.histplot(data=df, x="BloodPressure",color='pink')
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %% [markdown]
# <div dir="rtl">
#
# # פעמים רבות מסירים נתונים חריגים לפני שממשיכים לחקור ולעבד עוד את הנתונים.חישבו:
# # א) מדוע חשוב להסיר נתונים חריגים?
# # ב) האם תמיד נרצה להסיר נתונים חריגים?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# כיוון שהם משבשים את מדדי האמצע כמו המומצע ולא תמיד נרצה להוריד כי יכול להיות שהדאטואסט קטן מידי כדי להוריד
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl" align="center">
#
# ![image.png](data:image/png;base64,...)
# <br><br>
#
# <font color="red" size="8"><b>
# עצרו כאן! חכו להוראות המדריך ולהמשך המצגת
# </b></font><br><br><br>

# %% [markdown]
# <div dir="rtl">
#
# <font color="#6400E4" size="5"><b>
# חלק ב - האם ערכים חריגים משפיעים על סטיית תקן ושנות?
#
# </b></font>

# %% [markdown]
# <div dir="rtl">
# <body>
# <h3 dir="rtl">ברוכים החוזרים לקובץ הסוכרת.&nbsp; בחלק זה נעסוק בטיפול בערכים חריגים ובאנגלית outliers</h3>
# <p dir="rtl">&nbsp;</p>
# </body>
# </html>

# %% [markdown]
# <div dir="rtl">
#
# <h3 dir="rtl"> חשבו את השונות, סטיית התקן של המשתנה "מספר ההריונות"-&nbsp;<span style="color: #a31515;">Pregnancies.</span></h3>
#
#
# </body>
# </html>

# %%
# השלימו את הקוד כאן
print(df["Pregnancies"].var())
print(df["Pregnancies"].std())
# Out:
# 11.354056320621465
# 3.3695780626988694

# %% [markdown]
# <div dir="rtl">
#
# <h3 dir="rtl">צרו היסטוגרמה עבור המשתנה - מספר הריונות בחלוקה ל17 מחלקות</h3>

# %%
# השלימו את הקוד כאן
sns.histplot(data=df, x="Pregnancies", bins=17)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Count'>

# %% [markdown]
# <div dir="rtl">
#
# # מה צורת ההתפלגות כאן?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאןזנב ימני
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <h3 dir="rtl">צרו BOXPLOT עבור משתנה - מספר הריונות </h3>

# %%
#השלימו את הקוד כאן
sns.boxplot(data=df, x="Pregnancies")
# Out:
# <Axes: xlabel='Pregnancies'>

# %% [markdown]
# <div dir="rtl">
#
# # מה הם ערכי הקצה ?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן14,15,17.5
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <DIV dir="rtl">
#
# <font color="#6400E4" size="5"><b>
# כדי להעמיק בקשר בין הסיטוגרמה וסטיית תקן היה נחמד לצייר את סטיות התקן על הגרף אבל כיצד עושים זאת?
#
#
# <h2 dir="rtl">לשם כך נשתמש בעוד ספריה גרפית ושמה matplotlib.&nbsp; לא הכרנו אותה עד עכשיו מאחר ו-seaborn היא בעצם ממשק גישה נח ל-matplotlib!&nbsp;</h2>
#
# <h2 dir="rtl">לא נידרש להכיר אותה לעומק אלא רק פקודה אחת המשתמשת לציור קו אנכי על הגרפים שלנו -&nbsp;plt.axvline(x=value,c=<span style="color: #a31515;">&quot;r&quot;</span>).&nbsp; הפרמטר x פשוט מכיל את המיקום של הקו על ציר ה-x.&nbsp; פשוט, לא?&nbsp;</h2>
#
# <h2 dir="rtl">עכשיו לתרגיל: בעזרת הפקודה ציירו משני הצדדים&nbsp;של הממוצע, קו במרחק של סטיית תקן אחת.&nbsp;  האם זה מזכיר לכם משהו שלמדנו בשיעור? הוסיפו קו גם עבור הממוצע עצמו.</h2>
# </body>
# </html>

# %%
#השלימו את הקוד כאן

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
# איך נציג אותם יחד באותו החלון אחד מתחת לשני כמו שראינו במצגת?</h3>

# %% [markdown]
# <div dir="rtl">
# <h3 dir="rtl">לעיתים נרצה שה-hisplot וה-boxplot יהיו בדיוק  על אותם הצירים, כך שיהיה נוח לנתח את הנתונים.</h3>
#
# <h3 dir="rtl">&nbsp; לכן נשלב את שתיהן יחד, כך נוכל לראות את הסימון של סטיית התקן על ההיסטוגרמה (שזה בעצם דיאגרמת הקופסה)
#
# <h3 dir="rtl">לשם כך, נכיר עוד יכולת של matplotlib הניתנת לשימוש עם seaborn והיא היכלות לשלב גרפים באמצעות הפקודה subplot.</h3>
#
# <h3 dir="rtl">הסבר פשוט נמצא באתר&nbsp;<a href="https://www.w3schools.com/python/matplotlib_subplot.asp">https://www.w3schools.com/python/matplotlib_subplot.asp</a>&nbsp;</h3>
#
# <h3 dir="rtl">נסבך את הגרף עוד קצת, הוסיפו את שורת הקוד הבאה לפני שאתם קוראים ל-seaborn:</h3>
#
# <h3 dir="rtl">&nbsp;z, (ax_box, ax_hist) = plt.subplots(2, sharex=True).
# <h3 dir="rtl">
# המשתנים ax_boxו-ax_hist (שמות שאנו נתנו), ישמשו בפקודות של seaborn כערכים לפרמטר ax (עליו תוכלו לחקור בעצמכם).&nbsp; יתכן שתדרשו לשחק עם ההגדרות קצת עד שתיצרו את הגרף המבוקש. כמובן שיש להוסיף שני קווי סטיית תקן וממוצע.</h3>

# %%
#השלימו את הקוד כאן
import matplotlib.pyplot as plt
z, (ax_box, ax_hist) = plt.subplots(2, sharex=True)

# %% [markdown]
# <div dir="rtl">
#
# #**שימו לב! ב-Boxplot אנו עושים שימוש בחציון ואילו ב-Hisplot בממוצע.**

# %% [markdown]
# <div dir="rtl">
#
# #לאחר התיעצות עם מומחים, החלטנו שנשים שעברו **יותר מ-10 הריונות לא יכללו בחישובים** שלנו מאחר והם מקרים נדירים, לכן זהו התקן איתו נמשיך במחקר
#
# #אם נעבוד <strong>רק </strong>על שורות עם פחות מ-11 הריונות:</p>
#
# <p dir="rtl" style="text-align: justify;">מה תהיה השונות וסטיית התקן ?</p>
#
# <p dir="rtl" style="text-align: justify;">בכמה % תקטן סטיית התקן מול המצב המקורי?</p>
#
# <p dir="rtl" style="text-align: justify;">בכמה % יקטן מספר השורות ?</p>
#
# <p dir="rtl" style="text-align: justify;">מה היחס בין השינויים בסטיית התקן מול מספר השורות?&nbsp; מה זה אומר לנו?</p>
#
# <p dir="rtl" style="text-align: justify;">חשבו באמצעות פנדס <strong>ללא </strong>ביצוע שינויים ב-DF</p>
# </body>
# </html>

# %%
# הגדרת DF חדש ללא חריגים
df2=df.copy()
df2.drop(df.loc[df2["Pregnancies"]<11].index, inplace=True)
df2
#חישוב מדדים מחדש
print(df2["Pregnancies"].var())
print(df2["Pregnancies"].std())
# Out:
# 1.8012477718360071
# 1.342105723047185

# %%
#חישוב היחס
df2["Pregnancies"].var()
df2["Pregnancies"].std()

df_std=df["Pregnancies"].std()
df2_std=df2["Pregnancies"].std()
x = (df_std-df2_std)/df_std*100

df_num_rows = df.shape[0]
df2_num_rows = df2.shape[0]
y = (df_num_rows-df2_num_rows)/df_num_rows*100

x/y
df2_mean = df2["Pregnancies"].mean()

# %% [markdown]
# <div dir="rtl">
#
#
# <h3 dir="rtl">לאחר שיצרנו DF חדש, אנא ציירו displot ו-histplot והוסיפו קווים של סטיית תקן וממוצע.</h3>

# %%
#השלימו א תהקוד כאן
sns.displot(data=df2, x="Pregnancies", kde = True)

# %%
sns.histplot(data=df2, x="Pregnancies",kde=True)
# Out:
# <Axes: xlabel='Pregnancies', ylabel='Count'>

# %% [markdown]
# <div dir="rtl">
#
# # האם הורדת הנתונים בקובץ התונים השפעו על המדדים?  האם נכון להסיר את ערכי הקצה?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאןלא כיוון שהתעקנו את הנתונים לקובץ נתונים חדש ולפי דעתי נכון להוריד ערכי קצה כיוון שהם לא מועילים אלה רק מזיזים את ערך מדדי האמצע שלנו
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
# @title הריצו וענו - האם צורת ההתפלגות השתנתה כתוצאה מהורדת ערכי קצה?
sns.displot(df2["Pregnancies"],kind="kde")
plt.axvline(x=(df2_mean - df2_std),c="r")
plt.axvline(x=df2_mean,c="r")
plt.axvline(x=(df2_mean + df2_std),c="r")

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן כן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <h3 dir="rtl">מדעי נתונים מרבים מתעסקים רבות בסטיית תקן על מנת להבין טוב יותר&nbsp;את הנתונים.</h3>
#
# <h3 dir="rtl">במקרים רבים מדברים על &quot;הנתון נמצא במרחב של שתי סטיות תקן מהממוצע&quot; או &quot;רק המוכשרים באמת נמצאים במרחק של שלוש סטיות תקן או יותר&quot;.</h3>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
# </head>
# <body>
#     <img src="https://bookdown.org/pkaldunn/Book/13-NumericalQuant_files/figure-html/EmpRule-.gif" >
# </body>
# </html>

# %% [markdown]
# <div dir="rtl">
#
# <h3 dir="rtl">על מנת להקל על הניתוח של גרפים, בואו נוסיף שלושה קוים לפני הממוצע ושלושה אחרי ב-histplot וב-displot.&nbsp;</h3>
#
# <h3 dir="rtl">רמז - עשו זאת באמצעות לולאה.&nbsp;</h3>
# <h3 dir="rtl">את&nbsp; קו הממוצע הדגישו באמצעות הפרמטר&nbsp;linewidth=4.</h3>
# <p dir="rtl">&nbsp;</p>
# <h3 dir="rtl">&nbsp;</h3>
# </body>
# </html>

# %%
#השלם קוד כאן
sns.histplot(data=df2, x="Pregnancies")
df2_median = df2["Pregnancies"].median()
df2_mode = df2["Pregnancies"].mode()[0]
plt.axvline(x=df2_mean, linestyle='dashed', linewidth=4, label='Mean')
plt.axvline(x=df2_median, linestyle='dashed', label='Median')
plt.axvline(x=df2_mode, linestyle='dashed', label='Mode')

# %% [markdown]
# <h2 dir="rtl">מגוון האפשריות בספריות הגרפיות עצום ויש סכנה חמורה (לזמן שלכם) להתמכר אליהן. ידוע על מקרים שתלמידים שכחו ללכת לישון בגלל גרפים. <span style="background-color:#008000;">העצה </span>של טובי המומחים - השתמשו בגרפים פשוטים ככל האפשר.</h2>

# %% [markdown]
# <div dir="rtl">
#
# <font color="#6400E4" size="5"><b>
# חלק ג - המשך מחקר
#
# </b></font>

# %% [markdown]
# <h2 dir="rtl">
# נמשיך להעמיק בחקר הנתונים, לאחר שראינו את הערכים החריגים בדאטה בואו נבדוק לכמה אנשים יש לחץ דם ששווה לאפס.
# </h2>

# %%
#השלימו את הקוד כאן
df[df["BloodPressure"]==0].shape[0]
# Out:
# 35

# %% [markdown]
# <div dir="rtl">
#
#
# <h3 dir="rtl">לאחר שמצאנו את הערכים בהם לחץ הדם אפס - איך נוכל להתמודד איתם? ביחרו את הדרך שהכי נכונה לדעתכם , ממשו אותה ונמקו את תשובתכם!</h3>

# %%
#השלימו את הקוד כאן
x = df["BloodPressure"].mean()
df["BloodPressure"] = df["BloodPressure"].replace(0,x)
df[df["BloodPressure"]==0].shape[0]
# Out:
# 0

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# כדאי להוריד אותם כי לחץ דם 0 אומר שהאישה מתה
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
#
# <h3 dir="rtl">
# כעת הציגו את ההתפלגות אחרי (בונוס - להציג גם את ההתפלגות לפני וגם אחרי)
# </h3>

# %%
#השלימו את הקוד כאן
sns.histplot(data=df, x="BloodPressure", bins=17)
# Out:
# <Axes: xlabel='BloodPressure', ylabel='Count'>

# %% [markdown]
# <div dir="rtl">
#
#
# <h3 dir="rtl">
# האם זה השפיע על צורת ההתפלגות? שינוי טוב או פחות טוב?
# </h3>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# כן זה השפיע על ההתפלגות לטובה כיוון שעכשיו אין לנו ערכים שמזיזים לנו את המדדים והופכים אותם לפחות מדויקים
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ______________________________________________________________

# %% [markdown]
# <div dir="rtl">
# <h3 dir="rtl">
# חשבו את טווח הגילאים לפי העמודה outcome
# </h3>
# <h3 dir="rtl">
# <b> הסבר: </b>
# </h3>
# <h3 dir="rtl">
# 1. צרו DF חדש באמצעות groupby אשר יקבץ את ההכנסה על-ידי הגיל.
# </h3>
# <h3 dir="rtl">
# 2. על ה-groupby שיצרתם הפעילו את apply
# </h3>
#
# [היכנמסו לקישור הבא להסבר apply
# ](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.apply.html)
#
# <h3 dir="rtl">
# 3. בתוך apply צרו למדה שתבדוק את הטווח
# </h3>
# <h3 dir="rtl">
# <b> רמז :</b>
# בתוך הלמדה השתמשו בmin, max ופורמט
#  </h3>

# %%
#השלימו את הקוד כאן
df3 = df.groupby("Outcome")
x = df3.apply(lambda x: f"{x['Age'].min()} - {x['Age'].max()}")
x
# Out:
# Outcome
# 0    21 - 81
# 1    21 - 70
# dtype: object

# %% [markdown]
# <div dir="rtl">
#
#
# <h3 dir="rtl">
# צרו דיאגרמת קופסה שתציג את ה-DF שיצרתם בסעיף הקודם
# </h3>
# <h3 dir="rtl">
# האם לאחר ההגצה הגרפית קיבלתם יותר מידע?</h3>

# %%
#השלימו את הקוד כאן
sns.boxplot(data=df, x="Outcome", y="Age")
# Out:
# <Axes: xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאןכן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
# <h3 dir="rtl">
# נסכם את כל מה שלמדנו היום בסרטון
# </h3>
#
#
# [היכנסו לקישור הבא וצפו בסרטון סיכום
# ](https://www.youtube.com/watch?v=gpKEfVZlPj4)

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="6">
# <b>
# כל הכבוד! סיימתם את מטלת הבית של השיעור 16!
# </b>
# </font>
# </div>

# %% [markdown]
# <H5 dir=rtl align=center>
#
# ![end2.png](data:image/png;base64,...)
#
# </H5>
