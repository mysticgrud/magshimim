# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticgrud/magshimim/blob/main/%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_%D7%9E%D7%AA%D7%95%D7%93%D7%95%D7%AA_%D7%A9%D7%9C_%D7%9E%D7%97%D7%A8%D7%95%D7%96%D7%95%D7%AA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![up.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
# שיעור 3</font></b>
# <H1>
# <font color='#141C3A'>
# <b></b>
# </font>
# </H1>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="8">
# <b>
# תרגיל כיתה: מתודות של מחרוזות</b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size='5'><b>חלק א: חקר מתודות</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# כשיוצרים תוכנות מחשב או כשחוקרים מידע יש צורך לרכוש ידע חדש מהאינטרנט.<BR>
# קריאה של חומר חדש ושימוש בו הוא חלק חשוב מהיכולות שלנו כאנשים שעושים שימוש בטכנולוגיה.<BR>
# לכן גם אנחנו נתרגל קריאה של חומר מתוך אתר חיצוני באינטרנט והבנה שלו:<BR>
# נשתמש באתר בשם programiz שבו יש הסברים מפורטים וברורים.<BR>
# נשתמש באתר כדי לחקור את המתודות השונות שקיימות בשפת פייתון עבור מחרוזות.
# <br>
# המטרות שלנו בתרגול:<br>
# 1. ללמוד איך לעבוד עם מקור מידע חיצוני (ואפילו באנגלית - ונגלה שנצליח גם אם אנחנו לא אמריקאים שמדברים אנגלית כל היום :) ).<br>
# 2. ללמוד על מתודות חדשות של מחרוזות.<br>
# 3. לשחק עם מחרוזות לחקור ולהנות!
# <br>
# קיראו את ההנחיות בקפידה - והתחילו לחקור!
#
# <br>
#
# </div>

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size='4'><b>דוגמא: מחקר המתודה replace</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# בחלק הזה נראה דוגמא לתהליך שאותו תתבקשו לבצע מיד במחקר כל מתודה ומתודה.
# נדגים את התהליך על מתודה "replace" (באנגלית: להחליף).
#
# </div>

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4"><b>שלב 1: נקרא את תיאור המתודה</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# נכנס לאתר  <a href="https://www.programiz.com/python-programming/methods/string"> Programiz</a><href> ונחפש את המתודה שמעניינת אותנו. נוכל ללחוץ עליה ולקבל את הפירוט עליה (נשים לב שהמתודות מסודרות לפי השמות שלהן ע"פ סדר ה-ABC).<br>
# נתחיל לקרוא את ההסבר.
# <br>
# גם אם לא נבין את כל המילים באנגלית, חשוב לקרוא ולנסות להבין אפילו חלק: ב-99% מהפעמים לא צריך להכיר את כל המילים אלא רק את המילים החשובות כדי להבין את הסבר. כך לדוגמא, בהסבר של המתודה replace מספיק להכיר מילים כמו match - להתאים, replace- להחליף, ו-substring- תת מחרוזת (כלומר מספר תווים שהם חלק ממחרוזת גדולה יותר).
# <br>
# במידה ועדיין לא הבנו את תיאור המתודה, ניתן להיעזר בגוגל תרגום או לתרגם את כל האתר בעזרת התירגום האוטומטי של כרום.
# <br>
# לאחר שקראנו והבנו את ההסבר על פעולת המתודה, אנו יודעים שמה שהמתודה מבצעת זה להחליף את כל הפעמים שהן מופיע מחרוזת מסויימת, במחרוזת אחרת.
# <br>
# למשל בדוגמא שמופיעה למטה, כל פעם במופיעה תת המחרוזת "ba" היא תוחלף בתת המחרוזת "ro".<br>
# כך במקום המחרוזת "<b>ba</b>t <b>ba</b>ll" המתודה מחזירה את המחרוזת "<b>ro</b>t <b>ro</b>ll".
# <br><br>
#
# </div>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4"><b>שלב 2:  נבחן את הדוגמא</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# נוכל ללחוץ על הכפתור Run Code המופיע בתחתית התמונה שלמעלה, ויפתח בפנינו המסך הבא:<br>
# לאחר מכן נוכל להריץ את הקוד על ידי לחיצה על הכפתור Run בכחול, ונראה את הפלט של התכנית בצד ימין (שכרגע ריק כי לא הרצנו)
#
# </div>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4">
#
# <b>שלב 3: נשחק קצת עם הדוגמא</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# נריץ את הדוגמאות ונראה מה יקרה אם נשנה קצת דברים בקטע הקוד שאותו ראינו כעת. למשל אם נחליף את המחרוזת "ro" ב-"ne" נקבל תוצאה אחרת:
#
# </div>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4">
#
# <b>שלב 4: נקרא את ההסבר המפורט</b></font></div>

# %% [markdown]
# <div dir='rtl'> <font color='#9544fc' size="3"'>
#
# **תחביר: Syntax**</font>
#
# <font  size="4">
# הכותרת Syntax (באנגלית: תחביר) תתאר מה התחביר (כלומר, מה "השבלונה" או "התבנית") לשימוש במתודה.
# מתחתיה תופיע הכותרת Parameters (פרמטרים) שתספק הסבר קצר על כל מידע נוסף שצריך לספק למתודה.
# <br>
#
# <font  size="4">
# בעזרת ההסבר שמופיע למעלה, אנו יכולים להבין מה המשמעות של כל אחד מהפרמטרים:<br>
# 1.   old: תת המחרוזת אשר אותה אנו מעוניינים להחליף.
# 2.   new: תת המחרוזת החדשה, שנרצה שתופיע במקום תת המחרוזת old.
# 3.   count: מספר הפעמים שנרצה להחליף את תת המחרוזת הישנה בחדשה.
# <BR><b>נשים לב:</b> אם אנחנו לא נכניס כאן ערך, כל הפעמים שתופיע תת המחרוזת old היא תוחלף ב-new באופן אוטומטי.<BR><b>נשים לב 2:</b> שבגלל שכתוב Optional, כלומר אופציונלי (אינו חובה), אנו לא חייבים לספק מידע עבור הפרמטר הזה.

# %% [markdown]
# <img src="https://lh5.googleusercontent.com/bLBawOJDB8zKVY7jQYGU8RfcJQENIW9fxkvcaByVF9GuII8GeIGIXPxDSJ_j7zXhfsOG3t9Z9xzTLl9hUBHg7Re3tSzKaHMysW1aM1dZqmmVL6i7luatXl_xjgLYScG14tXdDbbLviWakYzPetI-BtydRyntGwf8B07CdReWUVyc2gMi3ec5fv-4uV2o2aoF">

# %% [markdown]
# <div dir='rtl'> <font color='#9544fc' size="3">
#
# **ערך החזרה: Return Value**</font><br>
# <font  size="4">
# לפעמים יופיע תיאור לגבי מה הערך שהמתודה מחזירה.<BR>
# לדוגמא, במקרה של המתודה replace יוחזר העתק של המחרוזת לאחר ההחלפה:
# <br><br>

# %% [markdown]
# <img src="https://lh3.googleusercontent.com/_UhjwE7WzjwDSYspWpgVJ_3z6X5x-wVhNL5wmet4rKTpMGkWwj39gABIH27mTXXoF5Ix_QUoBhlbeuYdVHfp55ELSKE8jv2WI6Iw99cw27Oi3i7CAm8waFD2GO4mYr77V3ihXypD2m3OtcyJEbql8Evii8aFWyIjkL6I-Fl8tMQwKnyz6EhhPgb2QMIQASy_">

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4"><b>שלב 5: חישבו על מקרי קצה</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# למקרים שהם לא השימוש הרגיל והאינטואיטיבי בקוד, קוראים "מקרי קצה".
# כדאי לנו לבדוק מה קורה במתודות במקרים אלו, כדי לוודא שההתנהגות היא כפי שנצפה לה.
# <br><br>

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4"><b>דוגמאות למקרי קצה</b></font></div>

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# ענו בקצרה: מה קורה כאשר תת המחרוזת להחלפה לא נמצאת בכלל במחרוזת המקורית? (רמז: ראינו דוגמא לכך קודם לכן)
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# name error</font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# ענו בקצרה: מה יקרה אם נשלח count שגדול ממספר המופעים של תת המחרוזת (בידקו בעצמכם וראו מה קורה)?
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# זה יתן את הגודל הגדול ביותר שיש בסטרינג הנתון
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
string = "example example example"
substring = "example"

max_occurrences = string.count(substring)
print("The maximum occurrences of '" + substring + "' in the string is: " + str(max_occurrences))
# Out:
# The maximum occurrences of 'example' in the string is: 3

# %% [markdown]
# <div dir="rtl">
# <font  size="4">
# ענו בקצרה: מה קורה אם תת המחרוזת שמחפשים היא מחרוזת ריקה? כלומר, מחרוזת שלא מכילה אף תו- ""? (בידקו בעצמכם וראו מה קורה)?
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# לא מואים כלום זה יוצא 0
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
thing = "dtyjhdy"
subs = ""
occurences = thing.count(subs)
print("times this:", subs, "appeared is", occurences)
# Out:
# times this:  appeared is 8

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4">
# <b> חקירה עצמאית:</b></font><br>
# <font  size="4">
# חיקרו כעת בעצמכם 3 מתודות נוספות באמצעות האתר שכעת ראינו, וענו על השאלות הבאות:
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# <font  size="4">**מתודה 1 - title:**<br>
# ענו למטה מה המתודה עושה, ותארו את הפרמטרים שהיא מקבלת. בנוסף בצעו 3 דוגמאות הרצה שונות של המתודה.
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
# הריצו דוגמה 1 כאן
#it capitalizez every word in the give string

wrod = "this is a sentence that i want to try this ethod on"
print(wrod.title())
# Out:
# This Is A Sentence That I Want To Try This Ethod On

# %%
# הריצו דוגמה 2 כאן
oops  = "i meant to write method instead of ethod in the sentence above"
print(oops.title())
# Out:
# I Meant To Write Method Instead Of Ethod In The Sentence Above

# %%
# הריצו דוגמה 3 כאן
anothaone = "i dont know an example for another example so ill just do a buncha stuff s'wrgfsaegf d'dd eqw!1 "
print(anothaone.title())
# Out:
# I Dont Know An Example For Another Example So Ill Just Do A Buncha Stuff S'Wrgfsaegf D'Dd Eqw!1

# %% [markdown]
# <div dir="rtl">
#
# <font  size="4">**מתודה 1 - isdigit:**<br>
# ענו למטה מה המתודה עושה, ותארו את הפרמטרים שהיא מקבלת. בנוסף בצעו 3 דוגמאות הרצה שונות של המתודה.
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
# הריצו דוגמה 1 כאן
#המתודה הזו בודקות אם סטריהג נתון הוא עשוי מספרות ורק מספרות
numberjumber = '3421233562'
print(numberjumber.isdigit())
# Out:
# True

# %%
# הריצו דוגמה 2 כאן
ex2 = "lettersuwu"
print(ex2.isdigit())
# Out:
# False

# %%
# הריצו דוגמה 3 כאן
ex3 = "beepboop123"
print(ex3.isdigit())
# Out:
# False

# %% [markdown]
# <div dir="rtl">
#
# <font  size="4">**מתודה 3 - endswith:**<br>
# ענו למטה מה המתודה עושה, ותארו את הפרמטרים שהיא מקבלת. בנוסף בצעו 3 דוגמאות הרצה שונות של המתודה.
# <br>
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
# הריצו דוגמה 1 כאן
#המתודה הזו בודקת האם התו האחרון בסטרינג הנתון תואמת את התו שצריך לבדוק
ex1 = "this is the first example"
print(ex1.endswith('example'))
# Out:
# True

# %%
# הריצו דוגמה 2 כאן
er1 = "goofy goober"
print(er1.endswith('goofy'))
# Out:
# False

# %%
# הריצו דוגמה 3 כאן
er2 = "this is the third sentence"
print(er2.endswith("123"))
# Out:
# False

# %% [markdown]
# <div dir="rtl"><font color='#9544fc' size="4">
#
# <b>תרגול נוסף:</b></font></div>

# %% [markdown]
# <div dir="rtl">
#
# <font color='#9544fc' size="3"> **1)**</font>
#
#
# <font  size="4">**א)**
# לפניכם מופיעה המחרוזת magshimim_str, נשים לב שהמחזורת מכילה אותיות קטנות וגם גדולות.<BR>
# חפשו באתר והיעזרו במתודה ()lower, והדפיסו למסך את אותה המחרוזת, אך הפעם נרצה שהמחרוזת תכיל רק אותיות קטנות.

# %%
magshimim_str = "MagshimiM AI Is Very FuN!"
# השלם את קטע הקוד כאן
print(magshimim_str.lower())
# Out:
# magshimim ai is very fun!

# %% [markdown]
# <div dir="rtl">
#
# <font  size="4">**ב)**
# לפניכם מופיעה המחרוזת magshimim_str, נשים לב שהמחרוזת מכילה הרבה מקפים (' - ') בתחילת המחרוזת ובסופה.<BR>
# הדפיסו למסך את המחרוזת אך ללא המקפים בתחילת המחרוזת ובסופה.<BR>
# חיקרו בעזרת האתר את המתודה ()strip על מנת לבצע זאת.

# %%
magshimim_str = "-----------Magshimim AI is very fun!-----------"
# השלם את קטע הקוד כאן
magshimim_str.strip('-')
# Out:
# 'Magshimim AI is very fun!'

# %% [markdown]
# <div dir="rtl">
# <font color='#9544fc' size="3">
#
# **2)** </font>
#
# <font  size="4">**א)**
# לפניכם מופיעה המחרוזת AI_str, אשר מכילה משפט מסויים על בינה מלאכותית (AI).<BR>
# אנו מעוניינים לדעת כמה פעמים המילה "AI" מופיעה במשפט.<BR>
# היעזרו באתר וחיקרו על המתודה ()count על מנת להדפיס למסך את כמות הפעמים שמופיעה המילה "AI".

# %%
AI_str = "machine learning and AI: the fascinating field of AI, is rapidly evolving. AI applications impact various industries, and AI's potential seems boundless."
AI_str.count("AI")
# השלם את קטע הקוד כאן
# Out:
# 4

# %% [markdown]
# <div dir="rtl">
#
# <font  size="4">**ב)**
# לפניכם מופיעה המחרוזת AI_str, היעזרו במתודה replace על מנת להחליף את המילה "AI" במחרוזת "artificial intelligence" **פעמיים בלבד**.
# הדפיסו למסך את המחרוזת לאחר ההחלפה, ובנוסף הדפיסו למסך  את כמות הפעמים שמופיעה המילה "AI" במחרוזת החדשה

# %%
AI_str = "machine learning and AI: the fascinating field of AI, is rapidly evolving. AI applications impact various industries, and AI's potential seems boundless."
replaced = AI_str.replace("AI", "artificial intelligence")
print(replaced)
# Out:
# machine learning and artificial intelligence: the fascinating field of artificial intelligence, is rapidly evolving. artificial intelligence applications impact various industries, and artificial intelligence's potential seems boundless.
