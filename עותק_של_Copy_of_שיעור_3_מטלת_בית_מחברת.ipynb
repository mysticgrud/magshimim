# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticgrud/magshimim/blob/class-3/%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_Copy_of_%D7%A9%D7%99%D7%A2%D7%95%D7%A8_3_%D7%9E%D7%98%D7%9C%D7%AA_%D7%91%D7%99%D7%AA_%D7%9E%D7%97%D7%91%D7%A8%D7%AA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![up.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
#  שיעור 3</font></b>
# <H1>
# <font color='#141C3A'>
# <b></b>
# </font>
# </H1>
# </div>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="8">
# <b>
# מטלת בית שיעור 3</b>
# </font>
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# במטלת הבית הזו אתם תהפכו להיות חוקרים פרטיים במספר תעלומות!
# <br>
# אך לפני שנגיע למטלות עלינו ללמוד ולתרגל עוד מספר נושאים.
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 1 - המשך פעולות על מחרוזות - הפקודה format</b>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
# <font  size="4">
# הפקודה format משמשת אותנו על מנת להוסיף ערכים לתוך תבנית של מחרוזת.
# <br>
# למשל כאשר אנחנו רוצים להדפיס תוצאה של חישוב, וגם הסבר קצר במילים באותה פקודת הדפסה, נוכל להיעזר ב-format.<BR><BR>
# ישנן 3 דרכים עיקריות לשימוש בפקודה format, ושלושתן יביאו לאותה התוצאה:<BR>
#
#
# **1)**
# </div>
# <div dir='ltr'>
#
# ```
# >>> print("My name is {name} and i am {age} years old".format(name='John', age=30))
# My name is John and i am 30 years old
# ```
# </div>
# <div dir='rtl'>
#
# **2)**
# </div>
#
# ```
# print("My name is {0} and i am {1} years old".format('John', 30))
# My name is John and i am 30 years old
# ```
# <div dir='rtl'>
#
# **3)**
# </div>
#
# ```
# print("My name is {} and i am {} years old".format('John', 30))
# My name is John and i am 30 years old
# ```

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף א'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4"> הסבירו במילים שלכם מהו לדעתכם המקור של שמה של הפקודה format? למה זה השם שלה לדעתכם?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# לדעתי מקור המילה format היא בדרך שבא מילילם מסוימות מסודרות במשפט

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ב'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">מדוע לפי דעתכם יוצרי שפת פייתון בחרו להמציא 3 דרכים שונות לשימוש בפקודה format?

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# לדתע יוצרי השפה בחרו להציא 3 דרגים שונות לשימוש בפקודה format כי ישנם הרבה דרכים בהם אפשר לעשות פעולות שונות בפייטון ולא כולם אפשר לעשות בהכרך עם אותם הדרכים.

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ג'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">נתונים שלושת המשתנים name, city ו-country:
# </div>
#
#
#
# ```
# >>> name = "Rina"
# >>> city = "Pardes Hanna"
# >>> country = "Israel"
# ```
#
# <div dir='rtl'>
# <font  size="4">
# ונתונה פקודת ההדפסה הבאה:
# </div>
#
# ```
# >>> print("Hi all! I am " + name + " and I am from " + city + ", " + country)
# Hi all! I am Rina and I am from Pardes Hanna, Israel
# ```
# <div dir='rtl'>
# <font  size="4">
# תרגמו את הפקודה הזו לפקודה העושה שימוש ב-format לפי דרך מספר 2.

# %%
# השלם את קטע הקוד כאן
print("Hi all! I am {0} and I am from {1}, {2}".format('Hanna', "Pardes Hanna", "Israel"))
# Out:
# Hi all! I am Hanna and I am from Pardes Hanna, Israel

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ד'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# נתון המשתנה cat:
# </div>
#
# ```
# >>> cat = "Mitzi"
# ```
# <div dir='rtl'>
# <font  size="4">
# ונתונה פקודת ההדפסה הבאה העושה שימוש ב-format לפי דרך 1:
# </div>
#
# ```
# >>> print("{cat_name} and {dog_name} do not get along...".format(cat_name=cat, dog_name="Rex"))
# Mitzi and Rex do not get along...
# ```
# <div dir='rtl'>
# <font  size="4">
# תרגמו את הפקודה הזו לפקודה העושה שימוש ב-format לפי דרך 3.

# %%
cat = "Mitzi"
# השלם את קטע הקוד כאן
print("{} and {} do not get along".format(cat, "rex"))
# Out:
# Mitzi and rex do not get along

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 2 - המשך פעולות על מחרוזות - גישה וחיתוך במחרוזות</b>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">צפו בסרטון [הבא](https://www.youtube.com/watch?v=kEhBr6MWx7Y&ab_channel=CyberSpaceCECVideos) וענו על השאלות הבאות:

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף א'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# עבור כל אחת מהמחרוזות בטבלה שלפניכם כתבו מהו מיקומו של התו המסומן בצהוב מההתחלה לסוף (מיקום חיובי) ומהסוף להתחלה (מיקום שלילי). <BR>
# שימו לב: השורה המסומנות באפור היא דוגמא.

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <div dir='rtl'>
# <font  size="4">
# ענו מה המיקומים המתאימים עבור כל אחת מהמחרוזות:

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# Artificial Intelligence:
# <br>
# - מיקום חיובי:
# <br><br>
# - מיקום שלילי:
#
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
print("Artificial Intelligence"[-3])
print("Artificial Intelligence"[20])
# Out:
# n
# n

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# data science:
# <br>
# - מיקום חיובי:
# <br><br>
# - מיקום שלילי:
#
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
print("data science"[1])
print("data science"[-11])
# Out:
# a
# a

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# machine learning:<br>
# - מיקום חיובי:
# <br><br>
# - מיקום שלילי:
#
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
print("machine learning"[10])
print("machine learning"[-6])
# Out:
# a
# a

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ב'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# בסרטון ראינו פעולה על מחרוזות אשר נקראת חיתוך מחרוזות, הבאנו לכם מספר דוגמאות נוספות והסברים מפורטים על מנת לוודא שהבנתם את נושא חיתוך המחרוזות
# <br>
# <b>דוגמא:</b>
# <br>
# עבור המחרוזת "Magshimim AI" והפלט הרצוי "Magshimi", קטע הקוד המתאים יהיה:
# </div>

# %%
print("Magshimim AI"[0:-4])
# Out:
# Magshimi

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הסבר:</b>
# <br>
# הפלט הרצוי Maghimi מתחיל בתחילת המחרוזת המקורית, לכן נרצה להתחיל מהמיקום 0, אנחנו רוצים להוריד 3 תווים מהסוף ולכן המיקום בו נרצה לסיים הוא 4- (ובפועל בגלל שהאינדקס הסופי לא כלול במחרוזת הסופית, יוסרו רק האינדקסים 1-, 2-, 3-
# <br></br>
# <b>למה האינדקס הסופי הוא 4- ולא 5-?</b>
# <br>
# כאשר אנחנו מבצעים חיתוך, האינדקס הסופי אינו נחשב, כלומר אם אנחנו כותבים -4 הכוונה היא שהאינדקס -4 לא יכלל בפלט הסופי.
# </font>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
# <font  size="4">
# <b>דוגמא נוספת-</b>
# עבור המחרוזת
# "Artificial Intelligence" והפלט הרצוי "ic", קטע הקוד המתאים יהיה:
#
# </font>
# </div>

# %%
print("Artificial Intelligence"[5:7])
# Out:
# ic

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הסבר:</b>
# <br>
# הפלט הרצוי ic נמצא באינדקסים: 5,6
# <br>
# לכן האינדקס ההתחלתי שלנו יהיה:5 והאינדקס הסופי שלנו יהיה 7
# <br></br>
# <b>למה האינדקס הסופי הוא 7 ולא 6?</b>
# <br>
# כאשר אנחנו מבצעים חיתוך, האינדקס הסופי אינו נחשב, כלומר אם אנחנו כותבים 7 הכוונה היא שהאינדקס 7 לא יכלל בפלט הסופי
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>טיפ למציאת האינדקס הסופי בחיתוך:</b>
# <br>
# נמצא את האינדקס בו הפלט שלנו מסתיים, ונוסיף לו 1+
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# עבור המחרוזות הבאות, והפלטים הבאים, כתבו את קטעי הקוד אשר יספקו את הפלט המתאים:
# </b>
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**א)** מהו קטע הקוד המתאים עבור המחרוזת "machine learning" והפלט הרצוי "chine learnin"?

# %%
# השלם את קטע הקוד כאן
print("machine learning"[2:])
# Out:
# chine learning

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**ב)** מהו קטע הקוד המתאים עבור המחרוזת "data science" והפלט הרצוי "dat"?

# %%
# השלם את קטע הקוד כאן
print("data science"[0:3])
# Out:
# dat

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ב'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# כעת נעבור לנושא קצת יותר מתקדם בחיתוך מחרוזות: חיתוך עם קפיצה של האינדקסים:
# <br>
# <b>דוגמא:</b>
# <br>
# עבור המחרוזת "0123456" והפלט הרצוי "024", קטע הקוד המתאים יהיה:
# </div>

# %%
print("0123456"[0:5:2])
# Out:
# 024

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הסבר:</b>
# <br>
# הפלט הרצוי "024" מתחיל בתחילת המחרוזת המקורית, לכן נרצה להתחיל מהמיקום 0, הפלט מסתיים באינדקס ה-4 ולכן האינדקס הסופי שלנו יהיה 5
# <br></br>
# השוני בפלט הזה מהסעיף הקודם הוא שאנחנו נרצה לקבל את הפלט בקפיצות של 2 ולכן הגדרנו בחיתוך קפיצה של 2
# </font>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# נתונה המחרוזת הבאה:
# </b>
# <br>
# </font>
# </div>

# %%
number = "012345678"

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**1**) מהו קטע הקוד המתאים עבור הפלט "1357"?

# %%
# השלם את קטע הקוד כאן
number = "012345678"
print(number[1:8:2])
# Out:
# 1357

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**2**) מהו קטע הקוד המתאים עבור הפלט "13579"?

# %%
# השלם את קטע הקוד כאן
number = "0123456789"
print(number[1:10:2])
# Out:
# 13579

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**3**) מהו קטע הקוד המתאים עבור הפלט "59"?

# %%
# השלם את קטע הקוד כאן
number = "0123456789"
print(number[5:10:4])
# Out:
# 59

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**4**) מהו קטע הקוד המתאים עבור הפלט "17"?

# %%
# השלם את קטע הקוד כאן
number = "0123456789"
print(number[1:8:6])
# Out:
# 17

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ג'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# ועכשיו אנחנו עוברים לנושא הקשה ביותר בחיתוך מחרוזות: חיתוך עם קפיצה שלילית
# <br>
# <b>
# ישנם 2 דברים עיקריים בהם חיתוך עם קפיצה שלילית שונה מחיתוך עם קפיצה חיובית:
# </b>
# <br>
# <ul>
#     <li>בגלל שהפעם אנחנו מתחילים מהסוף - האינדקס ההתחלתי יהיה גדול יותר מהאינדקס הסופי</li>
#     <li>בגלל שהקפיצה שלנו היא שלילית, נצטרך להוריד 1 מהאינדקס הסופי ולא להוסיף לו 1</li>
# </ul>
# <br>
# <b>דוגמאות:</b>
# <br>
# עבור המחרוזת "0123456" והפלט הרצוי "6543", קטע הקוד המתאים יהיה:
# </div>

# %%
print("0123456"[6:2:-1])
# Out:
# 6543

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הסבר:</b>
# <br>
# הפלט הרצוי "6543" מתחיל בסוף המחרוזת המקורית, לכן נרצה להתחיל מהמיקום 6(יכלנו להתחיל גם ממינוס 1), הפלט מסתיים באינדקס ה-3 ולכן האינדקס הסופי שלנו יהיה 2
# <br></br>
# <b>שמתם לב לשוני?</b>
# <br>
# האינדקס הסופי שלנו הוא 3, אך מכיוון שהקפיצה היא שלילית, במקום להוסיף אליו 1 הורדנו ממנו 1.
# <br>
# בנוסף, הפעם התחלנו מהאינדקס הגבוה וסיימנו באינדקס הנמוך
# </font>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
# <font  size="4">
# <b>דוגמא נוספת-</b>
# עבור המחרוזת
# "0123456" והפלט הרצוי "6543210", קטע הקוד המתאים יהיה:
#
# </font>
# </div>

# %%
print("0123456"[-1::-1])
# Out:
# 6543210

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>הסבר:</b>
# <br>
# הפלט הרצוי "6543210" מתחיל בסוף המחרוזת המקורית, לכן נרצה להתחיל מהמיקום 1-(יכלנו גם להתחיל מ6), הפלט מסתיים באינדקס ההתחלתי ולכן בגלל שאנחנו לא רוצים לעצור באף אינדקס אלא אנחנו רוצים להמשיך לאורך כל המחרוזת, נוכל להשאיר את המיקום של האינדקס הסופי ריק
# </font>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# נתונה המחרוזת הבאה:
# </b>
# <br>
# </font>
# </div>

# %%
number = "012345678"

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**1**) מהו קטע הקוד המתאים עבור הפלט "5432"?

# %%
number = "012345678"
print(number[5:1:-1])
# Out:
# 5432

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**2**) מהו קטע הקוד המתאים עבור הפלט "7531"?

# %%
number = "012345678"
print(number[7:0:-2])
# Out:
# 7531

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**3**) מהו קטע הקוד המתאים עבור הפלט "420"?

# %%
number = "012345678"
print(number[4::-2])
# Out:
# 420

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">**4**) מהו קטע הקוד המתאים עבור הפלט "17"?

# %%
number = "012345678"
print(number[1:9:6])
# Out:
# 17

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ד'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# עליכם לפענח מחרוזת נסתרת. כל שקיבלתם הוא מחרוזת צופן ואת הרמז: "מהסוף להתחלה בקפיצות של שתיים. האם תצליחו לגלות אותי?"
# מחרוזת הצופן:
#
# </div>
#
# ```
# encrypted_message = "!XgXnXiXcXiXlXsX XnXoXhXtXyXpX XgXnXiXnXrXaXeXlX XmXaX XI"
# ```
#
# <div dir='rtl'>
#
# <font  size="4">כיתבו פקודה שמדפיסה את ההודעה המפוענחת.<BR>**הדרכה:**
# מותר לכם להשתמש בפקודת חיתוך אחת בלבד בכדי לפענח את המחרוזת הנסתרת.
# <br>
# **רמז:** העזרו במרווח קפיצה שלילי.

# %%
encrypted_message = "!XgXnXiXcXiXlXsX XnXoXhXtXyXpX XgXnXiXnXrXaXeXlX XmXaX XI"
print(encrypted_message[::-2])
# Out:
# I am learning python slicing!

# %% [markdown]
# <div dir='rtl'>
# <font color='#E94F4B', size='4p'>
# <b>
# הידעתם?</b></font>
# <br>
# <font  size="4">
# בשאלות האחרונות התייחסנו למחרוזת כרצף שעליו אפשר לבצע פעולות המאפיינות רצף, כמו: גישה באמצעות סוגריים מרובעים וחיתוך (slicing).
# המידע שלמדנו בעל ערך רב: בהמשך נגלה שיש עוד רצפים בשפת פייתון שפועלים בדיוק באותו האופן, ולכן נוכל לכתוב קוד העושה בהם שימוש בלי בעיה!

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ה'** </font>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">צפו שוב בסרטון [הבא](https://www.youtube.com/watch?v=kEhBr6MWx7Y&ab_channel=CyberSpaceCECVideos) וענו מה לא היה מובן לכם בפעם הראשונה אך לאחר תרגול וצפייה נוספת הצלחתם להבין:

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# לא הבנתי בדיוק על מה הוא דיבר בכללי, אני מבינה הרבה יותר טוב ככשאני עושה דברים מאשר רק להקשיב לסרטון

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>טיפ:</b>
# <br>
# הרבה פעמים לא נבין חומר כלשהו על הפעם הראשונה, אנחנו נגלה שכאשר נחזור אחרי זמן כלשהו וננסה ללמוד את מה שלא הבנו, יהיה לנו הרבה יותר קל להבין אותו.
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 3 - עוצרים את גברת פאף</b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# דמיינו שאתם בלשים שעובדים על תיק של פושעת חלקלקה בשם גברת פאף.
# <br>
# המודיעין שלכם הצליח להשיג הודעה מוצפנת בה גב' פאף כתבה את המיקום בו יתבצע הפשע הבא שלה.על מנת לפענח את ההודעה תדרשו להשתמש בכישורי הפייתון שלכם.
#   השתמשו במחרוזות, מספרים וביטויים בוליאנים כדי לעקוב אחר הרמזים ולמנוע את הפשע של גברת פאף.
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# א. פענוח המסר
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# גברת פאף אוהבת להשתמש במשחקי מילים ומספרים בהודעות שלה. ההודעות שהיא שולחת תמיד משלבות מחרוזות ומספרים, משימתכם היא לפענח את ההודעה ולקבל את הרמז שטמון בה.
# <br>
# <b>
# ההודעה של גברת פאף:
# </b>
# <br>
# message = 'Axilpxlcv toorpfvv bmMgxyru bxczclecuaoeghsqo ipadyrjwevp jyiwsnys jemgeyup lhryoohworqmnq,ez ssIok tadocaworigero gmyseoijuvi intfaoph btgeqoau xmaimnezdao stfzailwnmzdgx ontfxhoxeoxmop mshuranphvbadrhpdaxs!pu!kn!zz!qj!'"
# <br></br>
# <b>רמז:</b>
# גברת פאף מאוד אוהבת לקפוץ
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# חלצו את כל המסר והדפיסו אותו.</b>
# <br>
# </font>
# </div>

# %%
message = 'Axilpxlcv toorpfvv bmMgxyru bxczclecuaoeghsqo ipadyrjwevp jyiwsnys jemgeyup lhryoohworqmnq,ez ssIok tadocaworigero gmyseoijuvi intfaoph btgeqoau xmaimnezdao stfzailwnmzdgx ontfxhoxeoxmop mshuranphvbadrhpdaxs!pu!kn!zz!qj!'

# פענחו את ההודעה כאן
print(message[0::3])
# Out:
# All of My clues are in my room, I dare you to go and find them hahaha!!!!!

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# ב. פתיחת הדלת
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# אחרי שהצלחתם לפענח את ההודעה, הגעתם לחדרה של גברת פאף אך הוא מכיל בתוכו סיסמה...
# <br>
# רגע לפני שויתרתם וחזרתם לתחנה הבחנתם בפתק שהוחבאה במשקוף.
# בפתק כתוב: "הסיסמה לחדר הסודי היא ההפך מהצבע האהוב עליי".
# <br>
# למזלכם אתם מכירים היטב את גברת פאף ויודעים שהצבע האהוב עליה הוא כחול
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# הקטע קוד הבא חסר, עליכם להשלים אותו כך שהמשתנה password יכיל בתוכו את הסיסמה. עליכם להשתמש אך ורק בחיתוך מחרוזות ובמתודה uppercase
# </b>
# <br>
# <b>רמז:</b>
# על מנת להפוך מחרוזת נוכל להשתמש בקפיצה שלילית
# </font>
# </div>

# %%
color = "Blue"

password = ((color.upper())[::-1])
print(password)
print("Is Password Correct:", password == "EULB")
# Out:
# EULB
# Is Password Correct: True

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="4">
# <b>
# ג. הבריחה
# </b>
# </font>
# </div>

# %% [markdown]
# <div dir='rtl'>
#
# <font  size="4">
# אחרי שעלינו על גברת פאף והגענו לחדרה גילינו שהיא מתכננת בריחה, עלינו למצוא את כלי התחבורה בו היא מתכננת לברוח וכך נוכל למצוא אותה ולעצור אותה!
# <br>
# הדרכה: קיראו על הפקודות שאינכם מכירים ב-Google או באתר Programiz
#
# </div>
#
#
#
# ```
# word = ???
# >>> print('e' in word)
# True
# >>> print(word.isspace())
# False
# >>> print(word.count('p'))
# 2
# >>> print(word.find('sh'))
# 5
# >>> print(word.endswith('e'))
# False
# >>> print(len(word))
# 9
# >>> print(word[-2::-4])
# ic
# >>> print(word.startswith('spa'))
# True
#
#
# ```

# %%
# השתמשו בתא הקוד על מנת למצוא את המילה
word =  "spaceship" #השלימו


print('e' in word)
print(word.isspace())
print(word.count('p'))
print(word.find('sh'))
print(word.endswith('e'))
print(len(word))
print(word[-2::-4])
print(word.startswith('spa'))
# Out:
# True
# False
# 2
# 5
# False
# 9
# ic
# True

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# כלי התחבורה איתו גברת פאף בורחת:
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# חללית

# %% [markdown]
# <div dir='rtl'>
# <font color='#9544fc' size='4'>
#
# **סעיף ה'** </font>

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="6">
# <b>
# כל הכבוד! הצלחתם למנוע את הפשע של גברת פאף!
# </b>
# </font>
# </div>

# %% [markdown]
# <center>
#
# ![Vw9v.gif](data:image/gif;base64,...)

# %% [markdown]
# <div dir="rtl" align="right">
# <font color='#9544fc' size="5">
# <b>
# תרגיל 4 - הכנה לקראת שיעור הבא</b>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# בתרגיל זה יוצגו בפניכם מספר קטעי קוד, בכל קטע קוד יופיע נושא חדש שעדיין לא למדתם, עליכם לנסות להבין מה המשמעות שלו ולענות במילים
# <br>
# </font>
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# הריצו את קטע הקוד הבא:
# </b>
# </font>
# </div>

# %%
num1 = 10
num2 = 5
is_bigger = num1 > 12 and num2 > 3

print(is_bigger)
# Out:
# False

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# מה לדעתכם האופרטור and עושה? כיצד הוא עובד?
# </b>
# <br>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# לדעתי האופרטור and אומר ועוד כלומר נותן עוד קריטריון אליו מה שצריך להתקיים מתקיים

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# הריצו את קטע הקוד הבא:
# </b>
# </font>
# </div>

# %%
num1 = 10
num2 = 5
is_bigger = num1 > 12 or num2 > 3

print(is_bigger)
# Out:
# True

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# מה לדעתכם האופרטור or עושה? כיצד הוא עובד?
# </b>
# <br>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# האופרטור or עושה או זה נותן לאחד משני האפשרויות להתקיים כדי שמה שיקרה יקרה לא בהכרח שניהם כמו בand

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# הריצו את קטע הקוד הבא:
# </b>
# </font>
# </div>

# %%
number = 10
print(not number < 5)
# Out:
# True

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# מה לדעתכם האופרטור not עושה? כיצד הוא עובד?
# </b>
# <br>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# האופרטור not לדעתי אומר גורם לכך שהדבר ההפוך ממה שיש אחריו יקרה נגיד בדוגמה כתוב שאם המספר הוא לא- קטן מ5 אז זה מדפיס true

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# הריצו את קטע הקוד הבא:
# </b>
# </font>
# </div>

# %%
number = 10

if number < 5:
    print("the number is not less than 5!")

print("hello everyone!")

if number > 2:
    print("the number is bigger than 2!")
# Out:
# hello everyone!
# the number is bigger than 2!

# %% [markdown]
# <div dir="rtl" align="right">
# <font  size="4">
# <b>
# מה לדעתכם if עושה? כיצד הוא עובד?
# </b>
# <br>
# </font>
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# לדעתי האופרטור if עושה את הפעולה אם, נגיד אם המספר גדול מ2 זה מדפיס את ההודעה באנגלית שהמספר גדול מ2

# %% [markdown]
# <div dir="rtl" align="center">
# <font color='#9544fc' size="6">
# <b>
# כל הכבוד! סיימתם את מטלת הבית של שיעור 3 והוסמכתם להיות החוקרים הראשיים של מגשימים AI
# </b>
# </font>
# </div>

# %% [markdown]
# <H5 dir=rtl align=center>
#
# ![end2.png](data:image/png;base64,...)
#
# </H5>
