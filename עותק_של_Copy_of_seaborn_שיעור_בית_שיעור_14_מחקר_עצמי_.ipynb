# %% [markdown]
# <a href="https://colab.research.google.com/github/mysticgrud/magshimim/blob/class-14/%D7%A2%D7%95%D7%AA%D7%A7_%D7%A9%D7%9C_Copy_of_seaborn_%D7%A9%D7%99%D7%A2%D7%95%D7%A8_%D7%91%D7%99%D7%AA_%D7%A9%D7%99%D7%A2%D7%95%D7%A8_14_%D7%9E%D7%97%D7%A7%D7%A8_%D7%A2%D7%A6%D7%9E%D7%99_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# ![up.png](data:image/png;base64,...)
#
# </center>

# %% [markdown]
# <div dir="rtl" align="center">
# <b><font color="Grey">
# שיעור 14</font></b>
# <H1>
# <font color='#141C3A'>
# <b></b>
# </font>
# </H1>
# </div>

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
#  טעינת הספריות
# </b></font>
#
# מוכנים? באו נצא לדרך ונוסיף את הספריות שאיתם נעבוד ונתחיל לחקור את המידע. הריצו את קטע הקוד והשתמשו בפעולות שאתם מכירים על מנת לחקור את קובץ הטיפים הנתון. איזה עמודות יש, איזה הוא מכיל, מה גודל המידע?
#
# </div>

# %%
# השלימו את הספריות
import seaborn as sns
import pandas as pd

tdf = sns.load_dataset('tips')
tdf
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#השלימו כאן את הקוד
tdf.info()
tdf.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# <div dir="rtl">
#
# **מה למדת אודות הנתונים?**

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# יש 7 עמודות ו244 שורות וגם למדנו את השמות של כל העמודות ומדדים סטטיסטיים על הנתונים
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl" align="center">
#
# ![images.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
# היכרות עם גרף פיזור
# </b></font>
#
# באו נכיר את הפונקציה בסיסית שיוצרת גרף פיזור של שני משתנים בספריה. הפונקציה לוקחת את משתני x ו-y
# כארגומנטים ויכול גם לקלוט ארגומנטים אחרים כגון צבע, גודל וסגנון כדי להתאים לתצוגת הנתונים שלנו
# <BR>
# x - הוא המשתנה בלתי תלוי.<BR>
# y - הוא המשתנה התלוי.<BR>
# data - הוא מסד הנתונים.<BR>
# <BR>
# <B> סעיף א</B>
#  הריצו את קטע קוד הבא, מה הגרף מציג?
# </div>

# %%
# Create a scatter plot of total bill vs. tip
sns.scatterplot(data=tdf, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# <div dir="rtl">
#
# <B>כתבו תשובה כאן:</B>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# הגרף מראה את הקשר בין גודל התשלום המלא לבין גןדל הטיפ
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <B>מעניין אילו נתונים משפיעים במיוחד על גובה התשלום ועל התשר?
# </b>
# <br>
#
#  באו ננסה לחקור זאת יחד.
#  [קראו כאן](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
#  על  כל הפרמטרים שמקבלת פעולת גרף הפיזור.
#  <br>
#  <B> סעיף ב</B>
#  מצאו פרמטר שיעזור לכם לבנות גרף פיזור כפי שראיתם לפני רגע, רק תהיה תוספת של צבע לפי מין הסועד. אישה או גבר על נקודות.

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
#
# ניתן להשתמש בפרמטרים<B> 'hue' ו-'style'</B>
# בשביל האפשרויות בתוך עמודה קטגורית וגם כדי לראות יותר ממשתנה קטגורי אחד בתוך אותו תרשים.
#
# <B> סעיף ג</B>
# נסו להשתמש בבפרמטר 'hue' בשביל המשתנה sex וב-'style' בשביל smoker<BR>
# חשבו על השאלות הבאות: מי יש יותר מעשנים או לא מעשנים? , מי מעשן יותר במקרה זה נשים או גברים?

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# ישנה פעולה שהיא משודרגת יותר לסוג גרף זה, קראו [עליה כאן](https://seaborn.pydata.org/generated/seaborn.relplot.html).
#
# <B> סעיף ד</B>
# קראו על פרמטר col והציגו גרף שמראה חלוקה ל2 עמודות של זמן הארוחה. השאירו את החלוקה לגברים ונשים כפי שעשיתם קודם.

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# <B>סעיף ה:</B>
# חשבו וענו על השאלות הבאות לפי הגרף<BR>
# מתי אוכלים יותר? בצהריים או בערב?
# מתי נותנים יותר טיפים ומשלמים יותר על ארוחה? ומי לדעתכם נותן יותר טיפים?
# <BR>הסבירו את תשובתכם
#
# <B>כתבו תשובה כאן:</B>
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <B>סעיף ו:</B>
# קראו על פרמטר SIZE למה הוא משמש? , נסו לשחק איתו ולהציג את כמות הסועדים בגרף  בנוסף למינם
#
# <B>כתבו תשובה כאן:</B>
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# <B>בונוס:</B>
# חפשו פונקציה , שתוסיף על הגרף הראשון שראינו קו , שנקרא קן רגרסיה שנראה האם אכן יש כיוון כלשהו לנתונים.
# איזה מסקנה עולה? ככל שהחשבון גבוהה יותר ערך הטיפ גבוהה יותר

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl" align="center">
#
# ![d2ru9du-044dc3e6-c3d4-482e-ae2a-1caf9932fa01.gif](data:image/gif;base64,...)

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
# היכרות עם גרף עמודות
# </b></font>
#
# עכשיו הגיע הזמן עם לעבודה עם גרף העמודות...
# <BR>
# <B> סעיף א</B>
#  הריצו את קטע קוד הבא, מה הגרף מציג? הסבירו , איזה מסקנה יכולה להתקבל על סמך הגרף?
# </div>

# %%
sns.barplot(data=tdf,  y="tip", x="day")

# %% [markdown]
# <div dir="rtl">
# <B>כתבו תשובה כאן:</B>
#
# </div>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <B> סעיף ב</B>
# שנו את הקוד כך שתראו את המידע אודות טיפים, באו ננסה לגלות עכשיו , מי נותן יותר טיפים?

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# <B> סעיף ג</B>
# השתמשו בפרטמר <B> 'hue'</B>, שלמדתם בגרף הקודם ונסו להוסיף אותו בחלוקה למעשנים. מה קיבלתם? מי נותן יותר טיפים מעשנים או לא מעשנים?

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# <B>סעיף ד</B>
# קראו עוד על הפרמטרים השונים של הפעולה ונסו לעשות גרף עמודות חדש אחר ממה שראיתם עד כה. יש מסקנה מעניינתם שהגרף שיצרתם מראה?

# %%
#השלימו כאן את הקוד

# %% [markdown]
# <div dir="rtl">
#
# <B>סעיף ה</B>
# הריצו את קטע קוד הבא, איזה גרף התקבל ומה הוא אומר? האם הוא מציג ערכים חריגים?
# <BR>
# <B>כתבו תשובה כאן:</B>
# <BR>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
# <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %%
sns.displot(tdf['tip'])

# %% [markdown]
# <div dir="rtl">
#
# <B>בונוס</B>
# חפשו מה ההבדל בין displot לבין  barplot
# <BR>
# <B>כתבו תשובה כאן:</B>
# <BR>

# %% [markdown]
# --------------------------------------------------------------------------------
# <div dir="rtl">
# <font color='#9EB9F6' size="4">
#  <b>
# ענו כאן
# </font>
# <br>
#
# --------------------------------------------------------------------------------

# %% [markdown]
# <div dir="rtl">
#
# <B>סעיף ו</B>
# אנו יכולים להשתמש בתנאים בעת יצירת גרפים , הריצו את הדוגמה הבאה והפכו את הגרף ללא מעשנים.
# <BR>

# %%
sns.displot(tdf[tdf['smoker'] == 'Yes']['total_bill'])

#צריכים לשנות את השורה העליונה בזו

# %% [markdown]
# <div dir="rtl">
#
# <B>בונוס</B>
# צרו גרף צבעוני מכל אחד מהסוגים שלמדתם...עמודות ופיזור. חפשו באינטרנט איך לשחק עם הצבעים וצרו גרף צבעוני ויפה לבחירתכם.

# %%
# השלימו את הקוד כאן

# %% [markdown]
# <div dir="rtl">
# <font color="#6400E4" size="5"><b>
# העשרה:
# </font>
#
# אם תרצו לדעת איזה עוד מאגרי מידע מובנים יש בספרייה תוכלו לעשות זאת ע"י פקודה הזו. אם תרצו לנסות לשחק עם עוד סוגי מידע ולבנות להם גרפים.

# %%
sns.get_dataset_names()
